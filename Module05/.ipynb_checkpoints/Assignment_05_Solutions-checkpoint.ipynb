# %% [markdown]
# # Assignment 5:  Due 10/7

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# # 1a)
#
# Read in the data set 'data/nobel.csv' into a DataFrame using Pandas .

# %%
df = pd.read_csv('data/nobel.csv')

# %% [markdown]
# # 1b)
#
# Display below the output from the DataFrame functions *info*.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  911 non-null    int64
#  1   category              911 non-null    object
#  2   prize                 911 non-null    object
#  3   motivation            823 non-null    object
#  4   prize_share           911 non-null    object
#  5   laureate_id           911 non-null    int64
#  6   laureate_type         911 non-null    object
#  7   full_name             911 non-null    object
#  8   birth_date            883 non-null    object
#  9   birth_city            883 non-null    object
#  10  birth_country         885 non-null    object
#  11  sex                   885 non-null    object
#  12  organization_name     665 non-null    object
#  13  organization_city     667 non-null    object
#  14  organization_country  667 non-null    object
# ...

# %% [markdown]
# # 1c)
#
# Use the *head* function to show the first 5 listings of the dataset.

# %%
df.head(5)
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %% [markdown]
# # Problem 2
#
# How many null ('NaN') values there are in each catagory? What is the total number of Null values in the DataFrame?

# %%
nNull = df.isnull().sum()
print(nNull)
# Out:
# year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               28
# birth_city               28
# birth_country            26
# sex                      26
# organization_name       246
# organization_city       244
# organization_country    244
# death_date              318
# death_city              335
# death_country           329
# dtype: int64

# %%
nNull.sum()
# Out:
# 1912

# %% [markdown]
# # Problem 3
#
# Make a histogram of the number of nobel prizes awarded per year. Around which decade (1900, 1910, 1920, ...) were the least amount of prizes awarded?

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.hist(df.year,bins = 25)
ax.set_xlabel('Year')
ax.set_ylabel('Prizes Awarded');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Problem 4
#
# Use groupby method to printout the number of prizes awarded to each category. Then histogram the categories. Your histogram should give the same number of prizes as your found in your printout. Which categroy has the most prizes?

# %%
df_cat = df.groupby('category').count()

# %%
df_cat['prize']
# Out:
# category
# Chemistry     175
# Economics      78
# Literature    113
# Medicine      211
# Peace         130
# Physics       204
# Name: prize, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.hist(df.category,bins = 25)
ax.set_xlabel('Category')
ax.set_ylabel('Prizes Awarded');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Problem 5
#
# Find percentage of the prizes were awarded to 1, 2, 3, and 4 people?

# %%
df_share = df.groupby('prize_share').count()

# %%
100 * df_share.prize / df_share.prize.sum()
# Out:
# prize_share
# 1/1    37.760703
# 1/2    33.589462
# 1/3    22.063666
# 1/4     6.586169
# Name: prize, dtype: float64

# %% [markdown]
# # Problem 6
#
# Determine how many males and females won the prize. Does the sum of male and female prizes add up to the total entries? If not, why?

# %%
df_male = df[df['sex'] == 'Male']
df_female = df[df['sex'] == 'Female']
df_unknown = df[ (df['sex'] != 'Female') & (df['sex'] != 'Male')]

# %%
print('Males who won the prize: {0}'.format(df_male.prize.count()))
print('Females who won the prize: {0}'.format(df_female.prize.count()))
total = df_male.prize.count() + df_female.prize.count()
# Out:
# Males who won the prize: 836
# Females who won the prize: 49

# %%
male_year = df_male.groupby('year').year.count() / total
female_year = df_female.groupby('year').year.count() / total

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.hist(df_male.year,label = 'Male');
ax.hist(df_female.year,label = 'Female');
ax.set_xlabel('Year')
ax.set_ylabel('Number of Winners')
ax.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Problem 7
#
# How many prizes were won by those whose birth country was United States of America?

# %%
sum(df['birth_country']=='United States of America')
# Out:
# 259

# %%
df.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %% [markdown]
# # Problem 8
#
# Determine the age that each of the prize winners were when they won the prize. Find the youngest and oldest to win the prize. Find the mean age to win the prize, and the standard deviation of it. Make a histogram of the distribution.
#
# ### Hint: You can use Pandas DatetimeIndex method
# > pd.DatetimeIndex(date).year
#
# Where *date* is given in a formate like year-month-day, the above will returen the year, hence the *.year* in the call above. Use 'shit+tab' on pandas.DatetimeIndex to learn more.

# %%
df.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %%
year = df.year - pd.DatetimeIndex(df.birth_date).year

# %%
old_loc = year.argmax()
young_loc = year.argmin()

print('Oldest: {0} at {1} years old'.format(df['full_name'][old_loc], year.max()))
print('Youngest: {0} at {1} years old'.format(df['full_name'][young_loc], year.min()))
print('Average age: {0:.1f} years and {1:.1f} years deviation'.format(year.mean(), year.std()))
# Out:
# Oldest: Leonid Hurwicz at 90.0 years old
# Youngest: Malala Yousafzai at 17.0 years old
# Average age: 59.5 years and 12.4 years deviation

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.hist(year);
ax.set_xlabel('Age (Years)')
ax.set_ylabel('Number of Winners');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Problem 9
#
# Make a copy of the current DataFrame. Drop the column *lauret_id* from the copied DataFrame (do this inplace so this column is gone).

# %%
df2 = df.copy()

# %%
df2 = df.drop('laureate_id',axis=1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-274-79d6a84d05e7> in <module>
# ----> 1 df2 = df.drop('laureate_id',axis=1,inplace = True)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  911 non-null    int64
#  1   category              911 non-null    object
#  2   prize                 911 non-null    object
#  3   motivation            823 non-null    object
#  4   prize_share           911 non-null    object
#  5   laureate_type         911 non-null    object
#  6   full_name             911 non-null    object
#  7   birth_date            883 non-null    object
#  8   birth_city            883 non-null    object
#  9   birth_country         885 non-null    object
#  10  sex                   885 non-null    object
#  11  organization_name     665 non-null    object
#  12  organization_city     667 non-null    object
#  13  organization_country  667 non-null    object
#  14  death_date            593 non-null    object
# ...

# %% [markdown]
# # Problem 10
#
# Add the age column you calculated in Problem 8 to the DataFrame.

# %%
df2['Award Age'] = year

# %%
df2
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# ...
